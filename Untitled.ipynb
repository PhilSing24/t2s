# %%
import pykx as kx

# %%
db = kx.DB(path='/home/philippe/new-tick-to-signal/hdb')
db.tables
# Out:
# ['quote_binance', 'trade_binance']

# %%
kx.q['trades'] = trade_binance
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 kx.q['trades'] = trade_binance
#
# NameError: name 'trade_binance' is not defined
